# %%
import pandas as pd
df = pd.read_csv('data/food_dot_com/RAW_recipes.csv').rename(columns={'id':'recipe_id'})
df=df.set_index('recipe_id')

df.head()
# Out:
#                                                  name  minutes  \
# recipe_id
# 137739     arriba   baked winter squash mexican style       55
# 31490                a bit different  breakfast pizza       30
# 112140                      all in the kitchen  chili      130
# 59389                              alouette  potatoes       45
# 44061              amish  tomato ketchup  for canning      190
#
#            contributor_id   submitted  \
# recipe_id
# 137739              47892  2005-09-16
# 31490               26278  2002-06-17
# 112140             196586  2005-02-25
# 59389               68585  2003-04-14
# 44061               41706  2002-10-25
#
#                                                         tags  \
# recipe_id
# 137739     ['60-minutes-or-less', 'time-to-make', 'course...
# 31490      ['30-minutes-or-less', 'time-to-make', 'course...
# 112140     ['time-to-make', 'course', 'preparation', 'mai...
# 59389      ['60-minutes-or-less', 'time-to-make', 'course...
# ...
